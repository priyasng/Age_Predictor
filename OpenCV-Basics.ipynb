# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: C:\Users\91911\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
#   Using cached opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\91911\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from opencv-python) (1.23.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.5.3-cp310-cp310-win_amd64.whl (7.2 MB)
# Requirement already satisfied: numpy>=1.17 in c:\users\91911\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\91911\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\91911\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (21.3)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.2.0-cp310-cp310-win_amd64.whl (3.3 MB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.36.0-py3-none-any.whl (950 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91911\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\91911\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.36.0 kiwisolver-1.4.4 matplotlib-3.5.3 pillow-9.2.0
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\91911\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: C:\Users\91911\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
 import cv2
from matplotlib import pyplot as plt

# %% [markdown]
#  # Plotting

# %%
img1=cv2.imread("agepredict/wom.jpg")

# %%
plt.imshow(img1)

# %% [markdown]
# # Arthematic Operations

# %%
img2=cv2.imread("agepredict/wo.jpg")

# %% [markdown]
# ## Addition

# %%
result=img1+img2

# %%
plt.imshow(result)

# %% [markdown]
# # Subtraction

# %%
result=img1-img2

# %%
plt.imshow(result)

# %% [markdown]
# # Multiplication

# %%
result=img1*img2

# %%
plt.imshow(result)

# %% [markdown]
# # Division

# %%
result=img1/img2
# Out:
# C:\Users\91911\AppData\Local\Temp\ipykernel_33852\2154265915.py:1: RuntimeWarning: divide by zero encountered in divide
#   result=img1/img2

# %%
plt.imshow(result)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Blurring

# %%
img1=cv2.imread("agepredict/wom.jpg")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HBGR2HSV)),plt.title("blurred")
plt.xticks([]),plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\91911\Desktop\Age_detector\OpenCV-Basics.ipynb Cell 21 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a> plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("original")
#       <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a> plt.xticks([]),plt.yticks([])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X26sZmlsZQ%3D%3D?line=7'>8</a> plt.subplot(122),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HBGR2HSV)),plt.title("blurred")
#       <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a> plt.xticks([]),plt.yticks([])
#      <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X26sZmlsZQ%3D%3D?line=9'>10</a> plt.show()
#
# AttributeError: module 'cv2' has no attribute 'COLOR_HBGR2HSV'

# %% [markdown]
# # Zoom

# %%
img1=cv2.imread("agepredict/wom.jpg")

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img1,(int(width*2),int(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %% [markdown]
# # Rotate

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.show(rotate)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\91911\Desktop\Age_detector\OpenCV-Basics.ipynb Cell 25 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> m=cv2.getRotationMatrix2D((width/2,height/2))
#       <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> rotate=cv2.warpAffine(img1,m,(height,width))
#       <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> plt.show(rotate)
#
# TypeError: getRotationMatrix2D() missing required argument 'angle' (pos 2)

# %% [markdown]
# # Translate

# %%
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img,m,(height,width))
plt.show(dst)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\91911\Desktop\Age_detector\OpenCV-Basics.ipynb Cell 26 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> m=np.float32([[1,0,50],[0,1,100]])
#       <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> dst=cv2.warpAffine(img,m,(height,width))
#       <a href='vscode-notebook-cell:/c%3A/Users/91911/Desktop/Age_detector/OpenCV-Basics.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> plt.show(dst)
#
# NameError: name 'np' is not defined
